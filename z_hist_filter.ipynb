# %%
import pandas as pd
import numpy as np
import array as arr

# %%
file = "resources/zillow_home_value_index_all.csv"
file_df = pd.read_csv(file, encoding='latin-1')
file_df.head()
# Out:
#    RegionID  RegionName      City State                             Metro  \
# 0     61639       10025  New York    NY       New York-Newark-Jersey City
# 1     84654       60657   Chicago    IL          Chicago-Naperville-Elgin
# 2     61637       10023  New York    NY       New York-Newark-Jersey City
# 3     91982       77494      Katy    TX  Houston-The Woodlands-Sugar Land
# 4     84616       60614   Chicago    IL          Chicago-Naperville-Elgin
#
#         CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2018-10  \
# 0  New York County         1  168300.0  168400.0  168400.0  ...  1072100
# 1      Cook County         2  160000.0  161000.0  161700.0  ...   350700
# 2  New York County         3  353100.0  353700.0  354200.0  ...  1391500
# 3    Harris County         4  210400.0  212200.0  212200.0  ...   336700
# 4      Cook County         5  194400.0  196100.0  197300.0  ...   429900
#
#    2018-11  2018-12  2019-01  2019-02  2019-03  2019-04  2019-05  2019-06  \
# ...

# %%
beaverton= "resources/output_realtor_beaverton_hotmarket.csv"
beaverton_df = pd.read_csv(beaverton)
beaverton_df.head()
# Out:
#    Unnamed: 0   Month  ZipCode        ZipName  Nielsen_HH_Rank  \
# 0        4046  201904    97005  Beaverton, OR             3970
# 1        4681  201904    97007  Beaverton, OR             1041
# 2        6548  201904    97006  Beaverton, OR             1238
# 3       13574  201904    97008  Beaverton, OR             2955
#
#    Hotness_Rank_County  Hotness_Rank_MoM  Hotness_Rank_YoY  Hotness_Score  \
# 0                  6.0             175.0           -1289.0      73.125830
# 1                  8.0            -633.0           -1763.0      68.406402
# 2                  2.0            -850.0            -599.0      82.384387
# 3                  1.0             372.0           -1080.0      84.943380
#
#    Supply_Score  Demand_Score
# 0     84.911748     61.339913
# 1     92.895553     43.917252
# 2     97.304991     67.463782
# 3     94.363257     75.523502

# %%
file_df.set_index('RegionID')
# Out:
#           RegionName               City State  \
# RegionID
# 61639          10025           New York    NY
# 84654          60657            Chicago    IL
# 61637          10023           New York    NY
# 91982          77494               Katy    TX
# 84616          60614            Chicago    IL
# 91940          77449               Katy    TX
# 93144          79936            El Paso    TX
# 91733          77084            Houston    TX
# 61616          10002           New York    NY
# 61807          10467           New York    NY
# 62037          11226           New York    NY
# 84640          60640            Chicago    IL
# 97564          94109      San Francisco    CA
# 61630          10016           New York    NY
# 92593          78660       Pflugerville    TX
# 74101          37013          Nashville    TN
# 71831          32162       The Villages    FL
# 62045          11235           New York    NY
# 62087          11375           New York    NY
# ...

# %%
file_df.dtypes
# Out:
# RegionID        int64
# RegionName      int64
# City           object
# State          object
# Metro          object
# CountyName     object
# SizeRank        int64
# 1996-04       float64
# 1996-05       float64
# 1996-06       float64
# 1996-07       float64
# 1996-08       float64
# 1996-09       float64
# 1996-10       float64
# 1996-11       float64
# 1996-12       float64
# 1997-01       float64
# 1997-02       float64
# 1997-03       float64
# 1997-04       float64
# 1997-05       float64
# 1997-06       float64
# 1997-07       float64
# 1997-08       float64
# 1997-09       float64
# 1997-10       float64
# 1997-11       float64
# 1997-12       float64
# 1998-01       float64
# 1998-02       float64
#                ...
# 2017-02         int64
# 2017-03         int64
# 2017-04         int64
# 2017-05         int64
# 2017-06         int64
# 2017-07         int64
# 2017-08         int64
# 2017-09         int64
# 2017-10         int64
# 2017-11         int64
# ...

# %%
oregon_df = file_df[file_df.State == "OR" ]
oregon_df.head()
# Out:
#      RegionID  RegionName         City State                         Metro  \
# 134     99142       97229     Portland    OR  Portland-Vancouver-Hillsboro
# 295     99252       97402       Eugene    OR                        Eugene
# 437     99048       97045  Oregon City    OR  Portland-Vancouver-Hillsboro
# 481     99251       97401       Eugene    OR                        Eugene
# 568     99093       97124    Hillsboro    OR  Portland-Vancouver-Hillsboro
#
#             CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2018-10  \
# 134   Multnomah County       135       NaN       NaN       NaN  ...   553800
# 295        Lane County       296   94800.0   95400.0   95900.0  ...   248800
# 437   Clackamas County       438  151600.0  152000.0  152100.0  ...   410700
# 481        Lane County       482  135000.0  136200.0  137300.0  ...   342900
# 568  Washington County       569  147300.0  148100.0  148900.0  ...   385700
#
# ...

# %%
city_df = oregon_df[oregon_df.City == "Beaverton" ]
city_df.head()
# Out:
#       RegionID  RegionName       City State                         Metro  \
# 1039     99012       97006  Beaverton    OR  Portland-Vancouver-Hillsboro
# 1123     99013       97007  Beaverton    OR  Portland-Vancouver-Hillsboro
# 3367     99014       97008  Beaverton    OR  Portland-Vancouver-Hillsboro
# 3865     99011       97005  Beaverton    OR  Portland-Vancouver-Hillsboro
# 4043    738092       97003  Beaverton    OR  Portland-Vancouver-Hillsboro
#
#              CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2018-10  \
# 1039  Washington County      1040  148800.0  149600.0  150600.0  ...   400400
# 1123  Washington County      1124  165700.0  166400.0  167200.0  ...   422300
# 3367  Washington County      3368  150000.0  150500.0  151100.0  ...   413300
# 3865  Washington County      3866  124700.0  125200.0  125600.0  ...   350100
# 4043  Washington County      4044  132600.0  133300.0  134000.0  ...   348700
#
# ...

# %%
city_df.set_index('RegionID')
# Out:
#           RegionName       City State                         Metro  \
# RegionID
# 99012          97006  Beaverton    OR  Portland-Vancouver-Hillsboro
# 99013          97007  Beaverton    OR  Portland-Vancouver-Hillsboro
# 99014          97008  Beaverton    OR  Portland-Vancouver-Hillsboro
# 99011          97005  Beaverton    OR  Portland-Vancouver-Hillsboro
# 738092         97003  Beaverton    OR  Portland-Vancouver-Hillsboro
#
#                  CountyName  SizeRank   1996-04   1996-05   1996-06   1996-07  \
# RegionID
# 99012     Washington County      1040  148800.0  149600.0  150600.0  151800.0
# 99013     Washington County      1124  165700.0  166400.0  167200.0  168300.0
# 99014     Washington County      3368  150000.0  150500.0  151100.0  151700.0
# 99011     Washington County      3866  124700.0  125200.0  125600.0  126200.0
# 738092    Washington County      4044  132600.0  133300.0  134000.0  134800.0
#
# ...

# %%
city_df.drop(city_df.columns[[2,3,4,5,6 ]],axis = 1, inplace = True)
city_df
# Out:
# C:\Users\mehar\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#       RegionID  RegionName   1996-04   1996-05   1996-06   1996-07   1996-08  \
# 1039     99012       97006  148800.0  149600.0  150600.0  151800.0  153100.0
# 1123     99013       97007  165700.0  166400.0  167200.0  168300.0  169500.0
# 3367     99014       97008  150000.0  150500.0  151100.0  151700.0  152400.0
# 3865     99011       97005  124700.0  125200.0  125600.0  126200.0  126800.0
# 4043    738092       97003  132600.0  133300.0  134000.0  134800.0  135600.0
#
#        1996-09   1996-10   1996-11  ...  2018-10  2018-11  2018-12  2019-01  \
# 1039  154400.0  155600.0  156800.0  ...   400400   403700   408600   411500
# ...

# %%
years= list(city_df.columns) 
years
# Out:
# ['RegionID',
#  'RegionName',
#  '1996-04',
#  '1996-05',
#  '1996-06',
#  '1996-07',
#  '1996-08',
#  '1996-09',
#  '1996-10',
#  '1996-11',
#  '1996-12',
#  '1997-01',
#  '1997-02',
#  '1997-03',
#  '1997-04',
#  '1997-05',
#  '1997-06',
#  '1997-07',
#  '1997-08',
#  '1997-09',
#  '1997-10',
#  '1997-11',
#  '1997-12',
#  '1998-01',
#  '1998-02',
#  '1998-03',
#  '1998-04',
#  '1998-05',
#  '1998-06',
#  '1998-07',
#  '1998-08',
#  '1998-09',
#  '1998-10',
#  '1998-11',
#  '1998-12',
#  '1999-01',
#  '1999-02',
#  '1999-03',
#  '1999-04',
#  '1999-05',
#  '1999-06',
#  '1999-07',
#  '1999-08',
#  '1999-09',
#  '1999-10',
#  '1999-11',
#  '1999-12',
#  '2000-01',
#  '2000-02',
#  '2000-03',
#  '2000-04',
#  '2000-05',
#  '2000-06',
#  '2000-07',
#  '2000-08',
#  '2000-09',
#  '2000-10',
#  '2000-11',
#  '2000-12',
#  '2001-01',
#  '2001-02',
#  '2001-03',
#  '2001-04',
#  '2001-05',
#  '2001-06',
#  '2001-07',
#  '2001-08',
#  '2001-09',
#  '2001-10',
#  '2001-11',
#  '2001-12',
# ...

# %%
years.remove('RegionID')
years.remove('RegionName')

# %%
years
# Out:
# ['1996-04',
#  '1996-05',
#  '1996-06',
#  '1996-07',
#  '1996-08',
#  '1996-09',
#  '1996-10',
#  '1996-11',
#  '1996-12',
#  '1997-01',
#  '1997-02',
#  '1997-03',
#  '1997-04',
#  '1997-05',
#  '1997-06',
#  '1997-07',
#  '1997-08',
#  '1997-09',
#  '1997-10',
#  '1997-11',
#  '1997-12',
#  '1998-01',
#  '1998-02',
#  '1998-03',
#  '1998-04',
#  '1998-05',
#  '1998-06',
#  '1998-07',
#  '1998-08',
#  '1998-09',
#  '1998-10',
#  '1998-11',
#  '1998-12',
#  '1999-01',
#  '1999-02',
#  '1999-03',
#  '1999-04',
#  '1999-05',
#  '1999-06',
#  '1999-07',
#  '1999-08',
#  '1999-09',
#  '1999-10',
#  '1999-11',
#  '1999-12',
#  '2000-01',
#  '2000-02',
#  '2000-03',
#  '2000-04',
#  '2000-05',
#  '2000-06',
#  '2000-07',
#  '2000-08',
#  '2000-09',
#  '2000-10',
#  '2000-11',
#  '2000-12',
#  '2001-01',
#  '2001-02',
#  '2001-03',
#  '2001-04',
#  '2001-05',
#  '2001-06',
#  '2001-07',
#  '2001-08',
#  '2001-09',
#  '2001-10',
#  '2001-11',
#  '2001-12',
#  '2002-01',
#  '2002-02',
# ...

# %%
myarray = np.asarray(years)
myarray
# Out:
# array(['1996-04', '1996-05', '1996-06', '1996-07', '1996-08', '1996-09',
#        '1996-10', '1996-11', '1996-12', '1997-01', '1997-02', '1997-03',
#        '1997-04', '1997-05', '1997-06', '1997-07', '1997-08', '1997-09',
#        '1997-10', '1997-11', '1997-12', '1998-01', '1998-02', '1998-03',
#        '1998-04', '1998-05', '1998-06', '1998-07', '1998-08', '1998-09',
#        '1998-10', '1998-11', '1998-12', '1999-01', '1999-02', '1999-03',
#        '1999-04', '1999-05', '1999-06', '1999-07', '1999-08', '1999-09',
#        '1999-10', '1999-11', '1999-12', '2000-01', '2000-02', '2000-03',
#        '2000-04', '2000-05', '2000-06', '2000-07', '2000-08', '2000-09',
#        '2000-10', '2000-11', '2000-12', '2001-01', '2001-02', '2001-03',
#        '2001-04', '2001-05', '2001-06', '2001-07', '2001-08', '2001-09',
#        '2001-10', '2001-11', '2001-12', '2002-01', '2002-02', '2002-03',
#        '2002-04', '2002-05', '2002-06', '2002-07', '2002-08', '2002-09',
# ...

# %%
len(myarray)
# Out:
# 280

# %%
melt_df= pd.melt(city_df, id_vars=['RegionName'], value_vars=myarray)
melt_df.head()
# Out:
#    RegionName variable     value
# 0       97006  1996-04  148800.0
# 1       97007  1996-04  165700.0
# 2       97008  1996-04  150000.0
# 3       97005  1996-04  124700.0
# 4       97003  1996-04  132600.0

# %%
melt_df.set_index('RegionName')
melt_df.head()
# Out:
#    RegionName variable     value
# 0       97006  1996-04  148800.0
# 1       97007  1996-04  165700.0
# 2       97008  1996-04  150000.0
# 3       97005  1996-04  124700.0
# 4       97003  1996-04  132600.0

# %%
clean = melt_df.rename(columns={'RegionName':'Zip_code','variable':'Date','value':'median_price'})
clean.head()
# Out:
#    Zip_code     Date  median_price
# 0     97006  1996-04      148800.0
# 1     97007  1996-04      165700.0
# 2     97008  1996-04      150000.0
# 3     97005  1996-04      124700.0
# 4     97003  1996-04      132600.0

# %%
clean.to_csv("resources/zip_median_1996_2019.csv")

# %%
sale_count = "resources/Sale_Counts_Zip.csv"
salecount_df = pd.read_csv(sale_count, encoding='latin-1')
salecount_df.head()
# Out:
#    RegionID  RegionName StateName  SizeRank  2008-03  2008-04  2008-05  \
# 0   61639.0       10025  New York         1      NaN      NaN      NaN
# 1   84654.0       60657  Illinois         2      NaN      NaN      NaN
# 2   61637.0       10023  New York         3      NaN      NaN      NaN
# 3   91982.0       77494     Texas         4     55.0     71.0     84.0
# 4   84616.0       60614  Illinois         5      NaN      NaN      NaN
#
#    2008-06  2008-07  2008-08  ...  2018-11  2018-12  2019-01  2019-02  \
# 0      NaN      NaN      NaN  ...     63.0     50.0     76.0     33.0
# 1      NaN      NaN      NaN  ...    109.0     99.0     94.0     78.0
# 2      NaN      NaN      NaN  ...     62.0     76.0     80.0     45.0
# 3     95.0    116.0     86.0  ...    149.0    170.0     86.0    113.0
# 4      NaN      NaN      NaN  ...    157.0     82.0     75.0     91.0
#
#    2019-03  2019-04  2019-05  2019-06  2019-07  seasAdj
# 0     47.0     56.0     35.0     70.0     80.0        0
# ...

# %%
salecount_df.set_index('RegionID')
salecount_df.head()
# Out:
#    RegionID  RegionName StateName  SizeRank  2008-03  2008-04  2008-05  \
# 0   61639.0       10025  New York         1      NaN      NaN      NaN
# 1   84654.0       60657  Illinois         2      NaN      NaN      NaN
# 2   61637.0       10023  New York         3      NaN      NaN      NaN
# 3   91982.0       77494     Texas         4     55.0     71.0     84.0
# 4   84616.0       60614  Illinois         5      NaN      NaN      NaN
#
#    2008-06  2008-07  2008-08  ...  2018-11  2018-12  2019-01  2019-02  \
# 0      NaN      NaN      NaN  ...     63.0     50.0     76.0     33.0
# 1      NaN      NaN      NaN  ...    109.0     99.0     94.0     78.0
# 2      NaN      NaN      NaN  ...     62.0     76.0     80.0     45.0
# 3     95.0    116.0     86.0  ...    149.0    170.0     86.0    113.0
# 4      NaN      NaN      NaN  ...    157.0     82.0     75.0     91.0
#
#    2019-03  2019-04  2019-05  2019-06  2019-07  seasAdj
# 0     47.0     56.0     35.0     70.0     80.0        0
# ...

# %%
oregoncount_df = salecount_df[salecount_df.StateName == "Oregon" ]
oregoncount_df.head()
# Out:
#      RegionID  RegionName StateName  SizeRank  2008-03  2008-04  2008-05  \
# 121   99142.0       97229    Oregon       122     63.0     65.0     79.0
# 280   99252.0       97402    Oregon       281     49.0     48.0     50.0
# 413   99048.0       97045    Oregon       414     47.0     49.0     47.0
# 456   99251.0       97401    Oregon       457     32.0     24.0     34.0
# 540   99093.0       97124    Oregon       541     45.0     57.0     46.0
#
#      2008-06  2008-07  2008-08  ...  2018-11  2018-12  2019-01  2019-02  \
# 121     85.0     66.0     75.0  ...     92.0     62.0     61.0     67.0
# 280     57.0     53.0     49.0  ...     61.0     58.0     52.0     32.0
# 413     47.0     40.0     40.0  ...     66.0     63.0     45.0     62.0
# 456     49.0     37.0     39.0  ...     27.0     38.0     27.0     25.0
# 540     51.0     52.0     52.0  ...     46.0     46.0     38.0     37.0
#
#      2019-03  2019-04  2019-05  2019-06  2019-07  seasAdj
# ...

# %%
ziplist= ["97003","97005","97006","97008","97007"]
citycount_df = oregoncount_df[oregoncount_df.RegionName.isin(ziplist)]
citycount_df.head()
# Out:
#       RegionID  RegionName StateName  SizeRank  2008-03  2008-04  2008-05  \
# 1018   99012.0       97006    Oregon      1019     28.0     33.0     38.0
# 1101   99013.0       97007    Oregon      1102     65.0     54.0     44.0
# 3355   99014.0       97008    Oregon      3356     15.0     14.0     26.0
# 3865   99011.0       97005    Oregon      3866     17.0     16.0     21.0
# 4048  738092.0       97003    Oregon      4049     18.0     25.0     30.0
#
#       2008-06  2008-07  2008-08  ...  2018-11  2018-12  2019-01  2019-02  \
# 1018     42.0     33.0     34.0  ...     49.0     39.0     29.0     50.0
# 1101     51.0     52.0     55.0  ...     90.0     68.0     33.0     51.0
# 3355     22.0     36.0     31.0  ...     28.0     30.0     26.0     23.0
# 3865     23.0     23.0     26.0  ...     23.0     25.0     19.0     18.0
# 4048     24.0     29.0     34.0  ...     27.0     24.0     20.0     22.0
#
#       2019-03  2019-04  2019-05  2019-06  2019-07  seasAdj
# ...

# %%
citycount_df.drop(citycount_df.columns[[0,2,3 ]],axis = 1, inplace = True)
citycount_df
# Out:
#       RegionName  2008-03  2008-04  2008-05  2008-06  2008-07  2008-08  \
# 1018       97006     28.0     33.0     38.0     42.0     33.0     34.0
# 1101       97007     65.0     54.0     44.0     51.0     52.0     55.0
# 3355       97008     15.0     14.0     26.0     22.0     36.0     31.0
# 3865       97005     17.0     16.0     21.0     23.0     23.0     26.0
# 4048       97003     18.0     25.0     30.0     24.0     29.0     34.0
#
#       2008-09  2008-10  2008-11  ...  2018-11  2018-12  2019-01  2019-02  \
# 1018     26.0     26.0     17.0  ...     49.0     39.0     29.0     50.0
# 1101     46.0     45.0     27.0  ...     90.0     68.0     33.0     51.0
# 3355     33.0     25.0     11.0  ...     28.0     30.0     26.0     23.0
# 3865     17.0     15.0     11.0  ...     23.0     25.0     19.0     18.0
# 4048     20.0     24.0     14.0  ...     27.0     24.0     20.0     22.0
#
#       2019-03  2019-04  2019-05  2019-06  2019-07  seasAdj
# ...

# %%
yearscount= list(citycount_df.columns) 
yearscount
# Out:
# ['RegionName',
#  '2008-03',
#  '2008-04',
#  '2008-05',
#  '2008-06',
#  '2008-07',
#  '2008-08',
#  '2008-09',
#  '2008-10',
#  '2008-11',
#  '2008-12',
#  '2009-01',
#  '2009-02',
#  '2009-03',
#  '2009-04',
#  '2009-05',
#  '2009-06',
#  '2009-07',
#  '2009-08',
#  '2009-09',
#  '2009-10',
#  '2009-11',
#  '2009-12',
#  '2010-01',
#  '2010-02',
#  '2010-03',
#  '2010-04',
#  '2010-05',
#  '2010-06',
#  '2010-07',
#  '2010-08',
#  '2010-09',
#  '2010-10',
#  '2010-11',
#  '2010-12',
#  '2011-01',
#  '2011-02',
#  '2011-03',
#  '2011-04',
#  '2011-05',
#  '2011-06',
#  '2011-07',
#  '2011-08',
#  '2011-09',
#  '2011-10',
#  '2011-11',
#  '2011-12',
#  '2012-01',
#  '2012-02',
#  '2012-03',
#  '2012-04',
#  '2012-05',
#  '2012-06',
#  '2012-07',
#  '2012-08',
#  '2012-09',
#  '2012-10',
#  '2012-11',
#  '2012-12',
#  '2013-01',
#  '2013-02',
#  '2013-03',
#  '2013-04',
#  '2013-05',
#  '2013-06',
#  '2013-07',
#  '2013-08',
#  '2013-09',
#  '2013-10',
#  '2013-11',
#  '2013-12',
# ...

# %%
yearscount.remove('RegionName')

# %%
myarraycount = np.asarray(yearscount)
myarraycount
# Out:
# array(['2008-03', '2008-04', '2008-05', '2008-06', '2008-07', '2008-08',
#        '2008-09', '2008-10', '2008-11', '2008-12', '2009-01', '2009-02',
#        '2009-03', '2009-04', '2009-05', '2009-06', '2009-07', '2009-08',
#        '2009-09', '2009-10', '2009-11', '2009-12', '2010-01', '2010-02',
#        '2010-03', '2010-04', '2010-05', '2010-06', '2010-07', '2010-08',
#        '2010-09', '2010-10', '2010-11', '2010-12', '2011-01', '2011-02',
#        '2011-03', '2011-04', '2011-05', '2011-06', '2011-07', '2011-08',
#        '2011-09', '2011-10', '2011-11', '2011-12', '2012-01', '2012-02',
#        '2012-03', '2012-04', '2012-05', '2012-06', '2012-07', '2012-08',
#        '2012-09', '2012-10', '2012-11', '2012-12', '2013-01', '2013-02',
#        '2013-03', '2013-04', '2013-05', '2013-06', '2013-07', '2013-08',
#        '2013-09', '2013-10', '2013-11', '2013-12', '2014-01', '2014-02',
#        '2014-03', '2014-04', '2014-05', '2014-06', '2014-07', '2014-08',
# ...

# %%
meltcount_df= pd.melt(citycount_df, id_vars=['RegionName'], value_vars=myarraycount)
meltcount_df.head()
# Out:
#    RegionName variable  value
# 0       97006  2008-03   28.0
# 1       97007  2008-03   65.0
# 2       97008  2008-03   15.0
# 3       97005  2008-03   17.0
# 4       97003  2008-03   18.0

# %%
clean_count=meltcount_df.rename(columns={'RegionName':'Zip_code','variable':'Date','value':'Sale_count'})
clean_count.head()
# Out:
#    Zip_code     Date  Sale_count
# 0     97006  2008-03        28.0
# 1     97007  2008-03        65.0
# 2     97008  2008-03        15.0
# 3     97005  2008-03        17.0
# 4     97003  2008-03        18.0

# %%
clean_count.to_csv("resources/zip_count_1996_2019.csv")

# %%
yearlist= [ '2019-04']
aprilmcount_df = clean_count[clean_count.Date.isin(yearlist)]
aprilmcount_df
# Out:
#      Zip_code     Date  Sale_count
# 665     97006  2019-04        66.0
# 666     97007  2019-04        83.0
# 667     97008  2019-04        32.0
# 668     97005  2019-04        28.0
# 669     97003  2019-04        50.0

# %%
yearlist= [ '2019-04']
aprilmedian_df = clean[clean.Date.isin(yearlist)]
aprilmedian_df
# Out:
#       Zip_code     Date  median_price
# 1380     97006  2019-04      408100.0
# 1381     97007  2019-04      430000.0
# 1382     97008  2019-04      422400.0
# 1383     97005  2019-04      353400.0
# 1384     97003  2019-04      356600.0

# %%
april_df =pd.merge(aprilmedian_df,aprilmcount_df)
april_df
# Out:
#    Zip_code     Date  median_price  Sale_count
# 0     97006  2019-04      408100.0        66.0
# 1     97007  2019-04      430000.0        83.0
# 2     97008  2019-04      422400.0        32.0
# 3     97005  2019-04      353400.0        28.0
# 4     97003  2019-04      356600.0        50.0

# %%
apr=april_df.drop(4)
apr
# Out:
#    Zip_code     Date  median_price  Sale_count
# 0     97006  2019-04      408100.0        66.0
# 1     97007  2019-04      430000.0        83.0
# 2     97008  2019-04      422400.0        32.0
# 3     97005  2019-04      353400.0        28.0

# %%
apr_zip =apr.rename(columns={'Zip_code': 'ZipCode'})
apr_zip
# Out:
#    ZipCode     Date  median_price  Sale_count
# 0    97006  2019-04      408100.0        66.0
# 1    97007  2019-04      430000.0        83.0
# 2    97008  2019-04      422400.0        32.0
# 3    97005  2019-04      353400.0        28.0

# %%
# Merge Hot Market dataframe to this Zillow april_df
merged_april2019 = pd.merge(beaverton_df, apr_zip, how='inner', on='ZipCode')
merged_april2019.head()
# Out:
#    Unnamed: 0   Month  ZipCode        ZipName  Nielsen_HH_Rank  \
# 0        4046  201904    97005  Beaverton, OR             3970
# 1        4681  201904    97007  Beaverton, OR             1041
# 2        6548  201904    97006  Beaverton, OR             1238
# 3       13574  201904    97008  Beaverton, OR             2955
#
#    Hotness_Rank_County  Hotness_Rank_MoM  Hotness_Rank_YoY  Hotness_Score  \
# 0                  6.0             175.0           -1289.0      73.125830
# 1                  8.0            -633.0           -1763.0      68.406402
# 2                  2.0            -850.0            -599.0      82.384387
# 3                  1.0             372.0           -1080.0      84.943380
#
#    Supply_Score  Demand_Score     Date  median_price  Sale_count
# 0     84.911748     61.339913  2019-04      353400.0        28.0
# 1     92.895553     43.917252  2019-04      430000.0        83.0
# 2     97.304991     67.463782  2019-04      408100.0        66.0
# ...

# %%
merged_april2019.drop(['Unnamed: 0'], axis = 1)
# Out:
#     Month  ZipCode        ZipName  Nielsen_HH_Rank  Hotness_Rank_County  \
# 0  201904    97005  Beaverton, OR             3970                  6.0
# 1  201904    97007  Beaverton, OR             1041                  8.0
# 2  201904    97006  Beaverton, OR             1238                  2.0
# 3  201904    97008  Beaverton, OR             2955                  1.0
#
#    Hotness_Rank_MoM  Hotness_Rank_YoY  Hotness_Score  Supply_Score  \
# 0             175.0           -1289.0      73.125830     84.911748
# 1            -633.0           -1763.0      68.406402     92.895553
# 2            -850.0            -599.0      82.384387     97.304991
# 3             372.0           -1080.0      84.943380     94.363257
#
#    Demand_Score     Date  median_price  Sale_count
# 0     61.339913  2019-04      353400.0        28.0
# 1     43.917252  2019-04      430000.0        83.0
# 2     67.463782  2019-04      408100.0        66.0
# 3     75.523502  2019-04      422400.0        32.0

# %%
apr.to_csv("resources/april_2019.csv")

# %%
dates = ['2008-03', '2008-04', '2008-05', '2008-06', '2008-07', '2008-08',
       '2008-09', '2008-10', '2008-11', '2008-12', '2009-01', '2009-02',
       '2009-03', '2009-04', '2009-05', '2009-06', '2009-07', '2009-08',
       '2009-09', '2009-10', '2009-11', '2009-12', '2010-01', '2010-02',
       '2010-03', '2010-04', '2010-05', '2010-06', '2010-07', '2010-08',
       '2010-09', '2010-10', '2010-11', '2010-12', '2011-01', '2011-02',
       '2011-03', '2011-04', '2011-05', '2011-06', '2011-07', '2011-08',
       '2011-09', '2011-10', '2011-11', '2011-12', '2012-01', '2012-02',
       '2012-03', '2012-04', '2012-05', '2012-06', '2012-07', '2012-08',
       '2012-09', '2012-10', '2012-11', '2012-12', '2013-01', '2013-02',
       '2013-03', '2013-04', '2013-05', '2013-06', '2013-07', '2013-08',
       '2013-09', '2013-10', '2013-11', '2013-12', '2014-01', '2014-02',
       '2014-03', '2014-04', '2014-05', '2014-06', '2014-07', '2014-08',
       '2014-09', '2014-10', '2014-11', '2014-12', '2015-01', '2015-02',
       '2015-03', '2015-04', '2015-05', '2015-06', '2015-07', '2015-08',
       '2015-09', '2015-10', '2015-11', '2015-12', '2016-01', '2016-02',
       '2016-03', '2016-04', '2016-05', '2016-06', '2016-07', '2016-08',
       '2016-09', '2016-10', '2016-11', '2016-12', '2017-01', '2017-02',
       '2017-03', '2017-04', '2017-05', '2017-06', '2017-07', '2017-08',
       '2017-09', '2017-10', '2017-11', '2017-12', '2018-01', '2018-02',
       '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08',
       '2018-09', '2018-10', '2018-11', '2018-12', '2019-01', '2019-02',
       '2019-03', '2019-04', '2019-05', '2019-06', '2019-07']

# %%
yearlymedian_df = clean[clean.Date.isin(dates)]
yearlymedian_df.head()
# Out:
#      Zip_code     Date  median_price
# 715     97006  2008-03      288000.0
# 716     97007  2008-03      321300.0
# 717     97008  2008-03      297300.0
# 718     97005  2008-03      253600.0
# 719     97003  2008-03      246900.0

# %%
yearlycount_df = clean_count[clean_count.Date.isin(dates)]
yearlycount_df.head()
# Out:
#    Zip_code     Date  Sale_count
# 0     97006  2008-03        28.0
# 1     97007  2008-03        65.0
# 2     97008  2008-03        15.0
# 3     97005  2008-03        17.0
# 4     97003  2008-03        18.0

# %%
years_2008_2019_df =pd.merge(yearlymedian_df,yearlycount_df)
years_2008_2019_df
# Out:
#      Zip_code     Date  median_price  Sale_count
# 0       97006  2008-03      288000.0        28.0
# 1       97007  2008-03      321300.0        65.0
# 2       97008  2008-03      297300.0        15.0
# 3       97005  2008-03      253600.0        17.0
# 4       97003  2008-03      246900.0        18.0
# 5       97006  2008-04      284100.0        33.0
# 6       97007  2008-04      316900.0        54.0
# 7       97008  2008-04      293500.0        14.0
# 8       97005  2008-04      249500.0        16.0
# 9       97003  2008-04      243100.0        25.0
# 10      97006  2008-05      279300.0        38.0
# 11      97007  2008-05      311200.0        44.0
# 12      97008  2008-05      288600.0        26.0
# 13      97005  2008-05      244500.0        21.0
# 14      97003  2008-05      238700.0        30.0
# 15      97006  2008-06      274700.0        42.0
# 16      97007  2008-06      305900.0        51.0
# 17      97008  2008-06      284100.0        22.0
# ...

# %%
years_2008_2019_df.to_csv("resources/z_2008-2019.csv")
